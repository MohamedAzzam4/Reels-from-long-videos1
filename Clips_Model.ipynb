# %% [markdown]
# ### Setting Up Base Functions

# %%
import os
import json
import re
from typing import List, Dict
import requests
from youtube_transcript_api import YouTubeTranscriptApi
from moviepy.editor import VideoFileClip, TextClip, CompositeVideoClip
import speech_recognition as sr
from google.cloud import texttospeech
import google.generativeai as genai
import arabic_reshaper
from bidi.algorithm import get_display
from pytube import YouTube
import yt_dlp
genai.configure(api_key= 'AIzaSyD4EuHeuUzCuPPkylR8kNDS0j7f8cLfyec')

# %%
from pytube import YouTube

# %%
def get_youtube_id(url):
    """Extract YouTube video ID from URL."""
    video_id = url.split("v=")[1]
    ampersand_pos = video_id.find("&")
    if ampersand_pos != -1:
        video_id = video_id[:ampersand_pos]
    print(f"Extracted YouTube ID: {video_id}")
    print('-----get_youtube_id is done-----')
    return video_id

def get_transcript(video_id, language ):
    """Get transcript from YouTube video."""
    try:
        transcript_list = YouTubeTranscriptApi.list_transcripts(video_id)
        
        try:
            transcript = transcript_list.find_manually_created_transcript([language])
        except:
            try:
                transcript = transcript_list.find_generated_transcript([language])
            except:
                try:
                    transcript = transcript_list.find_transcript([language])
                except:
                    print(f"No transcript found for language: {language}")
                    return None
        
        transcript_data = transcript.fetch()
        print(f"Successfully retrieved transcript for video {video_id}")
        

        with open(f"{video_id}_transcript.txt", "w", encoding="utf-8") as f:
            for entry in transcript_data:
                f.write(f"[{entry['start']:.2f}s - {entry['start'] + entry['duration']:.2f}s] {entry['text']}\n")    
        
        
        with open(f"{video_id}_transcript.txt", "r", encoding="utf-8") as f:
            file_text = f.read()
        print('-----get_transcript is done-----')
        return file_text
        
    except Exception as e:
        print(f"Error getting transcript: {e}")
        print('-----get_transcript is done-----')
        return None

def chunking_transcript(transcript: str) -> List[str]:
    """Split transcript into chunks of 50 lines each."""
    lis_transcript = transcript.split("\n")
    len(lis_transcript)
    transcript = ''
    chunks = []
    for y in range(0, len(lis_transcript), 50):
        for x in lis_transcript[y:y+50]:
            transcript += x + '\n'
        chunks.append(transcript)
        transcript = ''
    
    print('-----chunking_transcript is done-----')
    return chunks
    
def download_youtube_video(video_id, download_path='./'):
    """Download YouTube video and return the file path."""
    for i in range(5):
        try:
            # Construct the YouTube video URL
            video_url = f"https://www.youtube.com/watch?v={video_id}"
            
            # Create YouTube object using pytubefix
            yt = YouTube(video_url)
            
            # Get the highest resolution stream available
            stream = yt.streams.get_highest_resolution()
            
            # Download the video to the specified path
            print(f"Downloading video {video_id}...")
            downloaded_video = stream.download(output_path = download_path)
            video_name = os.path.basename(downloaded_video)

            # Get the absolute file path
            video_file_path = os.path.abspath(downloaded_video)
            
            print(f"Video downloaded successfully: {video_file_path}")
            print('-----download_youtube_video is done-----')
            return video_name  # Return the path to the downloaded video

        except Exception as e:
            print(f"An error occurred while downloading the video: {e}")
            print('-----download_youtube_video is done-----')
            return None
        
def download_youtube_video_yt_dlp(video_id, output_path='./'):
    try:
        """Download YouTube video using yt-dlp and return the file path."""
        video_url = f"https://www.youtube.com/watch?v={video_id}"
        ydl_opts = {
            'format': 'mp4',
            'outtmpl': f'{output_path}/{video_id}.mp4',
        }
        with yt_dlp.YoutubeDL(ydl_opts) as ydl:
            ydl.download([video_url])
        video_file_path = os.path.abspath(f'{output_path}/{video_id}.mp4')
        print(f"Video downloaded successfully: {video_file_path}")
        print('-----download_youtube_video is done-----')
        return video_file_path

    except Exception as e:
            print(f"An error occurred while downloading the video: {e}")
            print('-----download_youtube_video is done-----')
            return None
    
def gemini_clip_choosing(prompt, chunks):
    #chunks = chunking_transcript(get_transcript(video_id, 'ar'))

    model = genai.GenerativeModel("gemini-1.5-flash")
    chat = model.start_chat(
        history=[
            {"role": "user", "parts": 'Hi'},
            {"role": "model", "parts": "Great to meet you. What would you like to know?"},
        ]
    )

    chat.send_message(prompt)

    for chunk in chunks:
        chat.send_message(chunk)
        print("Chunk sent")


    response = chat.send_message("That was the last chunk, you can start generating the output now.")

    response_text = response.text.replace('```', '').replace('json', '')
    
    print(response_text)
    data = json.loads(r'{}'.format(response_text))

    print('-----gemini_clip_choosing is done-----')
    return data

# %%
prompt1 = '''
You are a professional YouTube Shorts editor with a talent for picking the best clips from long videos, focusing on moments that can go viral. You excel at choosing clips based on keywords that optimize SEO and at finding strong hooks like interesting facts or mysteries.

### Input:
- You will receive a transcript of the video, which contains every sentence spoken and its timestamp.
- The transcription may be in Arabic or English, and the Arabic could be Egyptian Arabic (العامية المصري).
- The video might feature a single speaker or multiple speakers, such as in a podcast.

### Your Task:
I need you to identify 5 clips to create YouTube Shorts from the transcript. Follow these guidelines:

1. **Clip Length**: Each clip should be between 60 seconds long. You can calculate the duration using the time provided in the brackets, use math to calculate the whole length e.g., `[0.24s - 60.24s]`.
   
2. **Key Moments**: Look for emotionally charged, funny, surprising, or highly informative moments. These are the clips that will resonate more with viewers and have a higher chance of being shared widely.

3. **Unique Insights**: Identify clips that offer valuable tips, expert opinions, or unique insights. These should be clear and concise.

4. **High Engagement Sections**: If the video has viewer comments or likes at specific timestamps, focus on these sections as they are likely to be engaging.

5. **Strong Hooks**: Make sure each clip has a strong hook at the beginning to grab attention. Hooks can be a surprising fact, mystery, or statement that encourages viewers to keep watching.

6. **Trends and Keywords**: Incorporate trending topics and relevant keywords to optimize for discovery and SEO.

### Format of Output:
Provide the clips in a JSON format. Each clip should contain:
- The start and end times in seconds.
- summary of the topic in Arabic.
- why you choosed it
- suggest a name for the clip
- give score out of 10 for the clip, score based on how engaging the clip will be with the audience

### Example Output:
```json
[
        {
            "start_time": "0.24s",
            "end_time": "60.24s",
            "summary": "انت تعالى انت هتفضل قاعد كده وغيرك بيعمل"
            "why i choosed it" :
            "suggest a name for the clip":
            "score": "8/10"
        },
]
```

### Some Things to Consider:
- you will recieve the video transcript in chunks you will start to generate your response when i tell you the following ``That was the last chunk, you can start generating the output now.``
- you may be tricked by thinking that you must generate 5 clips of every chunk, but you should generate 5 clips from the whole transcript
- don't say anything just give me the 5 clips with the output format as we discussed
- double check the duration of the clips to make sure they are 60 seconds long
- in summary section don't give me the whole trascription

Think twice and critically about the content you choose to include in the clips. Your goal is to create engaging and shareable content that will attract viewers to the full video.
    '''

# %%
video_path =  'الربح من الانترنت بكل الطرق.mp4'

output_path = "short_1.mp4"


"""Create a short video clip with captions."""
video = VideoFileClip(video_path)

# cut the video to the desired start and end time
for i in range(5):


    start_time = data[i]['start_time']
    end_time = data[i]['end_time']
    clip = video.subclip(float(start_time), float(end_time))
    
    #transcription
    transcript = get_transcript(get_youtube_id('https://www.youtube.com/watch?v=hI2Bo4TCSoY&ab_channel=NaderAhmed'), 'ar')
    output_path = "short_{}.mp4".format(i)
    
    # export video
    clip.write_videofile(output_path, codec="libx264", audio_codec="aac")

# %% [markdown]
# ### Making Clips

# %%
def get_start_end_time(transcript,data):
    transcript_lis = transcript.split('\n')
    start_time_index = []
    start_time_list = []
    end_time_index = []
    end_time_list = []

    for item in data :
        start_time = item['start_time']
        for i in transcript_lis :
            search_result = i.find(str(start_time))
            if search_result != -1:
                #print(transcript_lis.index(i))
                start_time_index.append(transcript_lis.index(i))
                start_time_list.append(start_time)
                break
            
            
        end_time = item['end_time']
        for i in transcript_lis :
            search_result = i.find(str(end_time))
            if search_result != -1:
                #print(transcript_lis.index(i))
                end_time_index.append( transcript_lis.index(i) ) 
                end_time_list.append(end_time) 
                break
            

        if len(start_time_index) > len(end_time_index):
            start_time_index.pop()
            start_time_list.pop()
        elif len(start_time_index) < len(end_time_index):
            end_time_index.pop()
            end_time_list.pop()
        '''
        if len(start_time_index) > len(end_time_index):
            end_time_index.append(-1)
            end_time_list.append('not found')
        elif len(start_time_index) < len(end_time_index):
            start_time_index.append(-1)
            start_time_list.append('not found')
        '''

    prompt_turnin_captions_into_json = ''' turn the following transcript inot json format :
    - The start and end times in seconds.
    - captions as it is
    example:
    ```json
    [
            {
                "start_time": "103.16",
                "end_time": "107.24",
                "captions": "بيشتغلوا برض حلو عادي جدا فلو انت داخل"
            },
    ]

    don't say anything just give me the json format as we discussed
    '''

    model = genai.GenerativeModel('gemini-pro')
    response = model.generate_content(prompt_turnin_captions_into_json + str(transcript_lis[start_time_index[1]:end_time_index[1]+1]))
    captions_clips = json.loads(response.text)
    
    print('-----get_start_end_time is done-----')
    return captions_clips



# here we need to put it in loop
def clip_videos(video_path, segment, output_path):
    """Create a short video clip with captions."""
    video = VideoFileClip(video_path)
    
    start_time = float(segment['start_time'].replace('s', '')) 
    end_time = float(segment['end_time'].replace('s', ''))
    
    clip = video.subclip(start_time, end_time)
    
    clip.write_videofile(output_path, codec="libx264", audio_codec="aac")
    print(f"Created short video: {output_path}")
    print('-----clip_videos is done-----')


def clips_with_captions(video_path, segment, output_path):
    """Create a short video clip with captions."""
    video = VideoFileClip(video_path)
    
    start_time = segment['start_time']
    end_time = segment['end_time']
    clip = video.subclip(start_time, end_time)
    
    # Reshape and prepare Arabic text for display
    reshaped_text = arabic_reshaper.reshape(segment['explanation'])
    bidi_text = get_display(reshaped_text)
    
    # Use a font that supports Arabic characters
    text_clip = TextClip(bidi_text, fontsize=24, color='white', font='Arial', stroke_color='black', stroke_width=1, method='caption', size=clip.size)
    text_clip = text_clip.set_position(('center', 'bottom')).set_duration(clip.duration)
    
    final_clip = CompositeVideoClip([clip, text_clip])
    
    final_clip.write_videofile(output_path, codec="libx264", audio_codec="aac")
    print(f"Created short video: {output_path}")
    print('-----clips_with_captions is done-----')

# %% [markdown]
# ### Main Function

# %%
def main(youtube_url, language='ar'):
    video_id = get_youtube_id(youtube_url)
    transcript = get_transcript(video_id, language)
    
    if not transcript:
        print("Failed to get transcript")
        return "Failed to get transcript"
    
    chunks = chunking_transcript(transcript)
    best_segments = gemini_clip_choosing(prompt1, chunks)
    print(best_segments)

    video_path = download_youtube_video_yt_dlp(video_id)
    print(video_path)
    
    shorts = []
    for i, segment in enumerate(best_segments):
        output_path = f"short_{video_id}_{i+1}.mp4"
        clip_videos(video_path, segment, output_path)
        shorts.append(output_path)
    
    print(f"Created {len(shorts)} shorts: {', '.join(shorts)}")
    print('-----main is done-----')
    return shorts

if __name__ == "__main__":
    youtube_url = input("Enter YouTube URL: ")
    language = input("Enter transcript language (e.g., en, ar): ")
    
    #Make New Folder
    folder_name = input('Enter Name of the Video: ')
    os.makedirs(folder_name, exist_ok=True)
    os.chdir(folder_name)
    
    result = main(youtube_url, language)
    print("Final result:", result)
# Out:
# Extracted YouTube ID: onSXVyCa1Go
# -----get_youtube_id is done-----
# Successfully retrieved transcript for video onSXVyCa1Go
# -----get_transcript is done-----
# -----chunking_transcript is done-----
# Chunk sent
# Chunk sent
# Chunk sent
# Chunk sent
#
# [
#     {
#         "start_time": "0.08s",
#         "end_time": "60.08s",
#         "summary": "نصائح لخلق توازن بين العمل والحياة الشخصية لضمان عطلة هادئة ومفيدة",
#         "why i choosed it": "The video starts with a relatable question many people face. It establishes a problem most viewers can identify with, setting up the solution of detaching from work during vacations.",
#         "suggest a name for the clip": "How To Actually Relax On Vacation",
#         "score": "9/10"
#     },
#     {
#         "start_time": "60.08s",
#         "end_time": "120.08s",
#         "summary": "يؤكد على أهمية فصل أنفسنا عن بيئة العمل خلال عطلة نهاية الأسبوع، مشيرا إلى ضرورة التواصل المحدود مع العمل خلال تلك الفترة",
#         "why i choosed it": "This clip emphasizes the importance of disconnecting from work notifications during vacation, which resonates with the audience's desire for true relaxation. It provides practical tips for setting boundaries with colleagues and managing communication.",
#         "suggest a name for the clip": "Turn Off Work Notifications: The Key To a Relaxing Vacation",
#         "score": "8/10"
#     },
#     {
#         "start_time": "120.08s",
#         "end_time": "180.08s",
#         "summary": "نصائح لتخصيص وقت للتفكير والهدوء والاستغفار خلال عطلة نهاية الأسبوع، مشيرا إلى أهمية هذه الأنشطة لتجديد النشاط والتركيز",
#         "why i choosed it": "This clip delves into the benefits of incorporating mindfulness practices like meditation or prayer during vacation.  It emphasizes the positive impact on mental clarity and rejuvenation, appealing to viewers seeking self-improvement.",
#         "suggest a name for the clip": "Recharge Your Mind: Mindfulness Practices for a Productive Vacation",
#         "score": "7/10"
#     },
#     {
#         "start_time": "180.08s",
#         "end_time": "240.08s",
#         "summary": "يشدد على أهمية ممارسة الرياضة خلال عطلة نهاية الأسبوع، مشيرا إلى فوائدها الجسدية والنفسية",
#         "why i choosed it": "This clip highlights the importance of physical activity during vacation. The speaker emphasizes its benefits for both physical and mental well-being, making it relevant to a broader audience.",
#         "suggest a name for the clip": "Vacation Fitness: Exercise For a Balanced Break",
#         "score": "8/10"
#     },
#     {
#         "start_time": "240.08s",
#         "end_time": "300.08s",
#         "summary": "يشرح أهمية قضاء وقت مع العائلة والأصدقاء خلال عطلة نهاية الأسبوع، مشيرا إلى تأثيره على السعادة والتوازن",
#         "why i choosed it": "This clip emphasizes the importance of connecting with loved ones during vacation, highlighting the social and emotional benefits.  The message of building strong relationships resonates with viewers seeking fulfillment beyond work.",
#         "suggest a name for the clip": "Strengthen Your Bonds: Spend Quality Time With Family and Friends",
#         "score": "9/10"
#     },
#     {
#         "start_time": "329.00s",
#         "end_time": "420.00s",
#         "summary": "نصائح لضمان عطلة نهاية أسبوع هادفة: تقييم الأسبوع الماضي، التخطيط للأسبوع القادم، والتواصل مع الأصدقاء",
#         "why i choosed it": "This clip provides practical advice on how to make the most of your weekend by reflecting on past achievements, planning for future goals, and prioritizing social connections.  The speaker encourages viewers to use their time off to enhance both their personal and professional lives.",
#         "suggest a name for the clip": "Weekend Productivity: Plan For Success & Recharge",
#         "score": "9/10"
#     },
#     {
#         "start_time": "420.00s",
#         "end_time": "510.00s",
#         "summary": "يؤكد على أهمية قضاء الوقت مع الأصدقاء خلال عطلة نهاية الأسبوع، مشيرا إلى فوائده في تعزيز التوازن وتجديد النشاط",
#         "why i choosed it": "This clip stresses the importance of prioritizing social interaction with friends during your weekend.  The speaker highlights the positive impact of social connections on mental and emotional well-being, making it a relatable message for viewers.",
#         "suggest a name for the clip": "The Power Of Friendship: Recharge With Your Crew On Vacation",
#         "score": "8/10"
#     },
#     {
#         "start_time": "510.00s",
#         "end_time": "600.00s",
#         "summary": "يشدد على أهمية عدم الضغط على النفس خلال عطلة نهاية الأسبوع، داعياً إلى الاسترخاء وتجنب الإرهاق",
#         "why i choosed it": "This clip emphasizes the importance of easing up and avoiding excessive stress during your weekend.  The speaker promotes the concept of balancing work and rest, ensuring a healthy and sustainable approach to life.",
#         "suggest a name for the clip": "Stress-Free Weekend: Relax and Recharge Your Battery",
#         "score": "7/10"
#     },
#     {
#         "start_time": "495.80s",
#         "end_time": "570.80s",
#         "summary": "نصائح لتغيير المكان خلال عطلة نهاية الأسبوع وتحسين الصحة النفسية",
#         "why i choosed it": "This clip connects changing your environment with improving mental health. The speaker emphasizes the impact of a change of scenery on well-being, making it a valuable takeaway for viewers seeking a more balanced lifestyle.",
#         "suggest a name for the clip": "Escape Your Routine: Change Your Location For Better Mental Health",
#         "score": "8/10"
#     },
#     {
#         "start_time": "570.80s",
#         "end_time": "660.80s",
#         "summary": "يشدد على أهمية الاهتمام بنفسك خلال عطلة نهاية الأسبوع، مؤكداً على ضرورة التوازن بين العمل والراحة",
#         "why i choosed it": "This clip promotes the importance of self-care and prioritizing relaxation during vacation.  It emphasizes the need for balance between work and rest, making this message relatable to viewers seeking a more fulfilling life.",
#         "suggest a name for the clip": "Self-Care Sunday: Take Time For You On Vacation",
#         "score": "9/10"
#     }
# ]
#
# -----gemini_clip_choosing is done-----
# [{'start_time': '0.08s', 'end_time': '60.08s', 'summary': 'نصائح لخلق توازن بين العمل والحياة الشخصية لضمان عطلة هادئة ومفيدة', 'why i choosed it': 'The video starts with a relatable question many people face. It establishes a problem most viewers can identify with, setting up the solution of detaching from work during vacations.', 'suggest a name for the clip': 'How To Actually Relax On Vacation', 'score': '9/10'}, {'start_time': '60.08s', 'end_time': '120.08s', 'summary': 'يؤكد على أهمية فصل أنفسنا عن بيئة العمل خلال عطلة نهاية الأسبوع، مشيرا إلى ضرورة التواصل المحدود مع العمل خلال تلك الفترة', 'why i choosed it': "This clip emphasizes the importance of disconnecting from work notifications during vacation, which resonates with the audience's desire for true relaxation. It provides practical tips for setting boundaries with colleagues and managing communication.", 'suggest a name for the clip': 'Turn Off Work Notifications: The Key To a Relaxing Vacation', 'score': '8/10'}, {'start_time': '120.08s', 'end_time': '180.08s', 'summary': 'نصائح لتخصيص وقت للتفكير والهدوء والاستغفار خلال عطلة نهاية الأسبوع، مشيرا إلى أهمية هذه الأنشطة لتجديد النشاط والتركيز', 'why i choosed it': 'This clip delves into the benefits of incorporating mindfulness practices like meditation or prayer during vacation.  It emphasizes the positive impact on mental clarity and rejuvenation, appealing to viewers seeking self-improvement.', 'suggest a name for the clip': 'Recharge Your Mind: Mindfulness Practices for a Productive Vacation', 'score': '7/10'}, {'start_time': '180.08s', 'end_time': '240.08s', 'summary': 'يشدد على أهمية ممارسة الرياضة خلال عطلة نهاية الأسبوع، مشيرا إلى فوائدها الجسدية والنفسية', 'why i choosed it': 'This clip highlights the importance of physical activity during vacation. The speaker emphasizes its benefits for both physical and mental well-being, making it relevant to a broader audience.', 'suggest a name for the clip': 'Vacation Fitness: Exercise For a Balanced Break', 'score': '8/10'}, {'start_time': '240.08s', 'end_time': '300.08s', 'summary': 'يشرح أهمية قضاء وقت مع العائلة والأصدقاء خلال عطلة نهاية الأسبوع، مشيرا إلى تأثيره على السعادة والتوازن', 'why i choosed it': 'This clip emphasizes the importance of connecting with loved ones during vacation, highlighting the social and emotional benefits.  The message of building strong relationships resonates with viewers seeking fulfillment beyond work.', 'suggest a name for the clip': 'Strengthen Your Bonds: Spend Quality Time With Family and Friends', 'score': '9/10'}, {'start_time': '329.00s', 'end_time': '420.00s', 'summary': 'نصائح لضمان عطلة نهاية أسبوع هادفة: تقييم الأسبوع الماضي، التخطيط للأسبوع القادم، والتواصل مع الأصدقاء', 'why i choosed it': 'This clip provides practical advice on how to make the most of your weekend by reflecting on past achievements, planning for future goals, and prioritizing social connections.  The speaker encourages viewers to use their time off to enhance both their personal and professional lives.', 'suggest a name for the clip': 'Weekend Productivity: Plan For Success & Recharge', 'score': '9/10'}, {'start_time': '420.00s', 'end_time': '510.00s', 'summary': 'يؤكد على أهمية قضاء الوقت مع الأصدقاء خلال عطلة نهاية الأسبوع، مشيرا إلى فوائده في تعزيز التوازن وتجديد النشاط', 'why i choosed it': 'This clip stresses the importance of prioritizing social interaction with friends during your weekend.  The speaker highlights the positive impact of social connections on mental and emotional well-being, making it a relatable message for viewers.', 'suggest a name for the clip': 'The Power Of Friendship: Recharge With Your Crew On Vacation', 'score': '8/10'}, {'start_time': '510.00s', 'end_time': '600.00s', 'summary': 'يشدد على أهمية عدم الضغط على النفس خلال عطلة نهاية الأسبوع، داعياً إلى الاسترخاء وتجنب الإرهاق', 'why i choosed it': 'This clip emphasizes the importance of easing up and avoiding excessive stress during your weekend.  The speaker promotes the ...
# [youtube] Extracting URL: https://www.youtube.com/watch?v=onSXVyCa1Go
# [youtube] onSXVyCa1Go: Downloading webpage
# [youtube] onSXVyCa1Go: Downloading ios player API JSON
# [youtube] onSXVyCa1Go: Downloading web creator player API JSON
# [youtube] onSXVyCa1Go: Downloading m3u8 information
# [info] onSXVyCa1Go: Downloading 1 format(s): 625
# [hlsnative] Downloading m3u8 manifest
# [hlsnative] Total fragments: 108
# [download] Destination: onSXVyCa1Go.mp4
# [download] 100% of    1.17GiB in 00:10:04 at 1.98MiB/s
# WARNING: onSXVyCa1Go: Possible MPEG-TS in MP4 container or malformed AAC timestamps. Install ffmpeg to fix this automatically
# Video downloaded successfully: f:\Programming\big projects\EditVideos\اجازتك سبب تعاستك\اجازتك سبب تعاستك\فيديو\onSXVyCa1Go.mp4
# -----download_youtube_video is done-----
# f:\Programming\big projects\EditVideos\اجازتك سبب تعاستك\اجازتك سبب تعاستك\فيديو\onSXVyCa1Go.mp4
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 35
#      32 os.makedirs(folder_name, exist_ok=True)
#      33 os.chdir(folder_name)
# ---> 35 result = main(youtube_url, language)
#      36 print("Final result:", result)
#
# Cell In[42], line 19, in main(youtube_url, language)
#      17 for i, segment in enumerate(best_segments):
#      18     output_path = f"short_{video_id}_{i+1}.mp4"
# ---> 19     clip_videos(video_path, segment, output_path)
#      20     shorts.append(output_path)
#      22 print(f"Created {len(shorts)} shorts: {', '.join(shorts)}")
#
# Cell In[37], line 77, in clip_videos(video_path, segment, output_path)
#      74 start_time = segment['start_time']
#      75 end_time = segment['end_time']
# ---> 77 clip = video.subclip(start_time, end_time)
#      79 clip.write_videofile(output_path, codec="libx264", audio_codec="aac")
#      80 print(f"Created short video: {output_path}")
#
# File <decorator-gen-54>:2, in subclip(self, t_start, t_end)
#
# File c:\Users\002\AppData\Local\Programs\Python\Python312\Lib\site-packages\moviepy\decorators.py:85, in preprocess_args.<locals>.wrapper(f, *a, **kw)
#      82     func_code = f.__code__ # Python 3
#      84 names = func_code.co_varnames
# ---> 85 new_a = [fun(arg) if (name in varnames) else arg
#      86          for (arg, name) in zip(a, names)]
#      87 new_kw = {k: fun(v) if k in varnames else v
#      88          for (k,v) in kw.items()}
#      89 return f(*new_a, **new_kw)
#
# File c:\Users\002\AppData\Local\Programs\Python\Python312\Lib\site-packages\moviepy\tools.py:95, in cvsecs(time)
#      92 factors = (1, 60, 3600)
#      94 if is_string(time):
# ---> 95     time = [float(f.replace(',', '.')) for f in time.split(':')]
#      97 if not isinstance(time, (tuple, list)):
#      98     return time
#
# ValueError: could not convert string to float: '0.08s'

# %%
clip_videos('F:\Programming\big projects\EditVideos\اجازتك سبب تعاستك\اجازتك سبب تعاستك\فيديو\onSXVyCa1Go.mp4',segment = segment, output_path='./' )
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File c:\Users\002\AppData\Local\Programs\Python\Python312\Lib\site-packages\moviepy\video\io\ffmpeg_reader.py:285, in ffmpeg_parse_infos(filename, print_infos, check_duration, fps_source)
#     284 index = -1 if is_GIF else 0
# --> 285 line = [l for l in lines if keyword in l][index]
#     286 match = re.findall("([0-9][0-9]:[0-9][0-9]:[0-9][0-9].[0-9][0-9])", line)[0]
#
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 clip_videos('F:\Programming\big projects\EditVideos\اجازتك سبب تعاستك\اجازتك سبب تعاستك\فيديو\onSXVyCa1Go.mp4',segment = segment, output_path='./' )
#
# Cell In[37], line 72, in clip_videos(video_path, segment, output_path)
#      70 def clip_videos(video_path, segment, output_path):
#      71     """Create a short video clip with captions."""
# ---> 72     video = VideoFileClip(video_path)
#      74     start_time = segment['start_time']
#      75     end_time = segment['end_time']
#
# File c:\Users\002\AppData\Local\Programs\Python\Python312\Lib\site-packages\moviepy\video\io\VideoFileClip.py:88, in VideoFileClip.__init__(self, filename, has_mask, audio, audio_buffersize, target_resolution, resize_algorithm, audio_fps, audio_nbytes, verbose, fps_source)
#      86 # Make a reader
#      87 pix_fmt = "rgba" if has_mask else "rgb24"
# ---> 88 self.reader = FFMPEG_VideoReader(filename, pix_fmt=pix_fmt,
#      89                                  target_resolution=target_resolution,
#      90                                  resize_algo=resize_algorithm,
#      91                                  fps_source=fps_source)
#      93 # Make some of the reader's attributes accessible from the clip
#      94 self.duration = self.reader.duration
#
# File c:\Users\002\AppData\Local\Programs\Python\Python312\Lib\site-packages\moviepy\video\io\ffmpeg_reader.py:35, in FFMPEG_VideoReader.__init__(self, filename, print_infos, bufsize, pix_fmt, check_duration, target_resolution, resize_algo, fps_source)
#      33 self.filename = filename
#      34 self.proc = None
# ---> 35 infos = ffmpeg_parse_infos(filename, print_infos, check_duration,
#      36                            fps_source)
#      37 self.fps = infos['video_fps']
#      38 self.size = infos['video_size']
#
# File c:\Users\002\AppData\Local\Programs\Python\Python312\Lib\site-packages\moviepy\video\io\ffmpeg_reader.py:289, in ffmpeg_parse_infos(filename, print_infos, check_duration, fps_source)
#     287         result['duration'] = cvsecs(match)
#     288     except:
# --> 289         raise IOError(("MoviePy error: failed to read the duration of file %s.\n"
#     290                        "Here are the file infos returned by ffmpeg:\n\n%s")%(
#     291                           filename, infos))
#     293 # get the output line that speaks about video
#     294 lines_video = [l for l in lines if ' Video: ' in l and re.search('\d+x\d+', l)]
#
# ig projects\EditVideos\اجازتك سبب تعاستك\اجازتك سبب تعاستك\فيديو\onSXVyCa1Go.mp4.
# Here are the file infos returned by ffmpeg:
#
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 9.2.1 (GCC) 20200122
#   configuration: --enable-gpl --enable-version3 --enable-sdl2 --enable-fontconfig --enable-gnutls --enable-iconv --enable-libass --enable-libdav1d --enable-libbluray --enable-libfreetype --enable-libmp3lame --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libopus --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libtheora --enable-libtwolame --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libzimg --enable-lzma --enable-zlib --enable-gmp --enable-libvidstab --enable-libvorbis --enable-libvo-amrwbenc --enable-libmysofa --enable-libspeex --enable-libxvid --enable-libaom --enable-libmfx --enable-amf --enable-ffnvcodec --enable-cuvid --enable-d3d11va --enable-nvenc --enable-nvdec --enable-dxva2 --enable-avisynth --enable-libopenmpt
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# ig projects\EditVideos\اجازتك سبب تعاستك\اجازتك سبب تعاستك\فيديو\onSXVyCa1Go.mp4: Invalid argument

# %%
youtube_url = 'https://www.youtube.com/watch?v=onSXVyCa1Go&ab_channel=AhmedShahin'
language = 'ar'
video_id = get_youtube_id(youtube_url)
transcript = get_transcript(video_id, language)
video_path = 'F:\Programming\big projects\EditVideos\onSXVyCa1Go.mp4'

if not transcript:
    print("Failed to get transcript")

chunks = chunking_transcript(transcript)
best_segments = gemini_clip_choosing(prompt1, chunks)
print(best_segments)

shorts = []
for i, segment in enumerate(best_segments):
    output_path = f"short_{video_id}_{i+1}.mp4"
    clip_videos(video_path, segment, output_path)
    shorts.append(output_path)

print(f"Created {len(shorts)} shorts: {', '.join(shorts)}")
print('-----main is done-----')

# %%
for i, segment in enumerate(best_segments):
    output_path = f"short_{video_id}_{i+1}.mp4"
    clip_videos('onSXVyCa1Go.mp4', segment, output_path)
    shorts.append(output_path)
# Out:
#
#
#
# t:   2%|▏         | 34/1799 [03:17<03:00,  9.76it/s, now=None]
#
#
#
# t:   2%|▏         | 34/1799 [03:17<03:00,  9.76it/s, now=None]
# Moviepy - Building video short_onSXVyCa1Go_1.mp4.
# Moviepy - Writing video short_onSXVyCa1Go_1.mp4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[29], line 3
#       1 for i, segment in enumerate(best_segments):
#       2     output_path = f"short_{video_id}_{i+1}.mp4"
# ----> 3     clip_videos('onSXVyCa1Go.mp4', segment, output_path)
#       4     shorts.append(output_path)
#
# Cell In[28], line 79, in clip_videos(video_path, segment, output_path)
#      75 end_time = float(segment['end_time'].replace('s', ''))
#      77 clip = video.subclip(start_time, end_time)
# ---> 79 clip.write_videofile(output_path, codec="libx264", audio_codec="aac")
#      80 print(f"Created short video: {output_path}")
#      81 print('-----clip_videos is done-----')
#
# File <decorator-gen-73>:2, in write_videofile(self, filename, fps, codec, bitrate, audio, audio_fps, preset, audio_nbytes, audio_codec, audio_bitrate, audio_bufsize, temp_audiofile, rewrite_audio, remove_temp, write_logfile, verbose, threads, ffmpeg_params, logger)
#
# File c:\Users\002\AppData\Local\Programs\Python\Python312\Lib\site-packages\moviepy\decorators.py:54, in requires_duration(f, clip, *a, **k)
#      52     raise ValueError("Attribute 'duration' not set")
#      53 else:
# ---> 54     return f(clip, *a, **k)
#
# File <decorator-gen-72>:2, in write_videofile(self, filename, fps, codec, bitrate, audio, audio_fps, preset, audio_nbytes, audio_codec, audio_bitrate, audio_bufsize, temp_audiofile, rewrite_audio, remove_temp, write_logfile, verbose, threads, ffmpeg_params, logger)
#
# File c:\Users\002\AppData\Local\Programs\Python\Python312\Lib\site-packages\moviepy\decorators.py:135, in use_clip_fps_by_default(f, clip, *a, **k)
#     130 new_a = [fun(arg) if (name=='fps') else arg
#     131          for (arg, name) in zip(a, names)]
#     132 new_kw = {k: fun(v) if k=='fps' else v
#     133          for (k,v) in k.items()}
# --> 135 return f(clip, *new_a, **new_kw)
#
# File <decorator-gen-71>:2, in write_videofile(self, filename, fps, codec, bitrate, audio, audio_fps, preset, audio_nbytes, audio_codec, audio_bitrate, audio_bufsize, temp_audiofile, rewrite_audio, remove_temp, write_logfile, verbose, threads, ffmpeg_params, logger)
#
# File c:\Users\002\AppData\Local\Programs\Python\Python312\Lib\site-packages\moviepy\decorators.py:22, in convert_masks_to_RGB(f, clip, *a, **k)
#      20 if clip.ismask:
#      21     clip = clip.to_RGB()
# ---> 22 return f(clip, *a, **k)
#
# File c:\Users\002\AppData\Local\Programs\Python\Python312\Lib\site-packages\moviepy\video\VideoClip.py:300, in VideoClip.write_videofile(self, filename, fps, codec, bitrate, audio, audio_fps, preset, audio_nbytes, audio_codec, audio_bitrate, audio_bufsize, temp_audiofile, rewrite_audio, remove_temp, write_logfile, verbose, threads, ffmpeg_params, logger)
#     292 if make_audio:
#     293     self.audio.write_audiofile(audiofile, audio_fps,
#     294                                audio_nbytes, audio_bufsize,
#     295                                audio_codec, bitrate=audio_bitrate,
#     296                                write_logfile=write_logfile,
#     297                                verbose=verbose,
#     298                                logger=logger)
# --> 300 ffmpeg_write_video(self, filename, fps, codec,
#     301                    bitrate=bitrate,
#     302                    preset=preset,
#     303                    write_logfile=write_logfile,
#     304                    audiofile=audiofile,
#     305                    verbose=verbose, threads=threads,
#     306                    ffmpeg_params=ffmpeg_params,
#     307                    logger=logger)
#     309 if remove_temp and make_audio:
#     310     if os.path.exists(audiofile):
#
# File c:\Users\002\AppData\Local\Programs\Python\Python312\Lib\site-packages\moviepy\video\io\ffmpeg_writer.py:220, in ffmpeg_write_video(clip, filename, fps, codec, bitrate, preset, withmask, write_logfile, audiofile, verbose, threads, ffmpeg_params, logger)
#     213 with FFMPEG_VideoWriter(filename, clip.size, fps, codec = codec,
#     214                             preset=preset, bitrate=bitrate, logfile=logfile,
#     215                             audiofile=audiofile, threads=threads,
#     216                             ffmpeg_params=ffmpeg_params) as writer:
#     218     nframes = int(clip.duration*fps)
# --> 220     for t,frame in clip.iter_frames(logger=logger, with_times=True,
#     221                                     fps=fps, dtype="uint8"):
#     222         if withmask:
#     223             mask = (255*clip.mask.get_frame(t))
#
# File c:\Users\002\AppData\Local\Programs\Python\Python312\Lib\site-packages\moviepy\Clip.py:472, in Clip.iter_frames(self, fps, with_times, logger, dtype)
#     470 logger = proglog.default_bar_logger(logger)
#     471 for t in logger.iter_bar(t=np.arange(0, self.duration, 1.0/fps)):
# --> 472     frame = self.get_frame(t)
#     473     if (dtype is not None) and (frame.dtype != dtype):
#     474         frame = frame.astype(dtype)
#
# File <decorator-gen-29>:2, in get_frame(self, t)
#
# File c:\Users\002\AppData\Local\Programs\Python\Python312\Lib\site-packages\moviepy\decorators.py:89, in preprocess_args.<locals>.wrapper(f, *a, **kw)
#      85 new_a = [fun(arg) if (name in varnames) else arg
#      86          for (arg, name) in zip(a, names)]
#      87 new_kw = {k: fun(v) if k in varnames else v
#      88          for (k,v) in kw.items()}
# ---> 89 return f(*new_a, **new_kw)
#
# File c:\Users\002\AppData\Local\Programs\Python\Python312\Lib\site-packages\moviepy\Clip.py:93, in Clip.get_frame(self, t)
#      91         return frame
#      92 else:
# ---> 93     return self.make_frame(t)
#
# File c:\Users\002\AppData\Local\Programs\Python\Python312\Lib\site-packages\moviepy\Clip.py:136, in Clip.fl.<locals>.<lambda>(t)
#     133     apply_to = []
#     135 #mf = copy(self.make_frame)
# --> 136 newclip = self.set_make_frame(lambda t: fun(self.get_frame, t))
#     138 if not keep_duration:
#     139     newclip.duration = None
#
# File c:\Users\002\AppData\Local\Programs\Python\Python312\Lib\site-packages\moviepy\Clip.py:187, in Clip.fl_time.<locals>.<lambda>(gf, t)
#     184 if apply_to is None:
#     185     apply_to = []
# --> 187 return self.fl(lambda gf, t: gf(t_func(t)), apply_to,
#     188                keep_duration=keep_duration)
#
# File <decorator-gen-29>:2, in get_frame(self, t)
#
# File c:\Users\002\AppData\Local\Programs\Python\Python312\Lib\site-packages\moviepy\decorators.py:89, in preprocess_args.<locals>.wrapper(f, *a, **kw)
#      85 new_a = [fun(arg) if (name in varnames) else arg
#      86          for (arg, name) in zip(a, names)]
#      87 new_kw = {k: fun(v) if k in varnames else v
#      88          for (k,v) in kw.items()}
# ---> 89 return f(*new_a, **new_kw)
#
# File c:\Users\002\AppData\Local\Programs\Python\Python312\Lib\site-packages\moviepy\Clip.py:93, in Clip.get_frame(self, t)
#      91         return frame
#      92 else:
# ---> 93     return self.make_frame(t)
#
# File c:\Users\002\AppData\Local\Programs\Python\Python312\Lib\site-packages\moviepy\video\io\VideoFileClip.py:113, in VideoFileClip.__init__.<locals>.<lambda>(t)
#     109     self.mask.fps = self.fps
#     111 else:
# --> 113     self.make_frame = lambda t: self.reader.get_frame(t)
#     115 # Make a reader for the audio, if any.
#     116 if audio and self.reader.infos['audio_found']:
#
# File c:\Users\002\AppData\Local\Programs\Python\Python312\Lib\site-packages\moviepy\video\io\ffmpeg_reader.py:184, in FFMPEG_VideoReader.get_frame(self, t)
#     182 else:
#     183     self.skip_frames(pos-self.pos-1)
# --> 184 result = self.read_frame()
#     185 self.pos = pos
#     186 return result
#
# File c:\Users\002\AppData\Local\Programs\Python\Python312\Lib\site-packages\moviepy\video\io\ffmpeg_reader.py:120, in FFMPEG_VideoReader.read_frame(self)
#     117 w, h = self.size
#     118 nbytes= self.depth*w*h
# --> 120 s = self.proc.stdout.read(nbytes)
#     121 if len(s) != nbytes:
#     123     warnings.warn("Warning: in file %s, "%(self.filename)+
#     124            "%d bytes wanted but %d bytes read,"%(nbytes, len(s))+
#     125            "at frame %d/%d, at time %.02f/%.02f sec. "%(
#    (...)
#     129            "Using the last valid frame instead.",
#     130            UserWarning)
#
# KeyboardInterrupt:
